# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Image size
IMG_SIZE = 48
BATCH_SIZE = 64

# Data generators
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
   r"C:\Users\user\OneDrive\Desktop\emotion\train",
    target_size=(IMG_SIZE, IMG_SIZE),
    color_mode="grayscale",
    batch_size=BATCH_SIZE,
    class_mode="categorical"
)

test_data = test_datagen.flow_from_directory(
   r"C:\Users\user\OneDrive\Desktop\emotion\test",
    target_size=(IMG_SIZE, IMG_SIZE),
    color_mode="grayscale",
    batch_size=BATCH_SIZE,
    class_mode="categorical"
)

# CNN model
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(48,48,1)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(7, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# Train
model.fit(
    train_data,
    epochs=50,
    validation_data=test_data
)

# Save model
model.save("emotion_model.h5")
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 46, 46, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 23, 23, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 21, 21, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 10, 10, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 7)              │         3,591 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,145,351 (4.37 MB)
#  Trainable params: 1,145,351 (4.37 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 38s 82ms/step - accuracy: 0.2704 - loss: 1.7594 - val_accuracy: 0.3314 - val_loss: 1.6314
# Epoch 2/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 36s 79ms/step - accuracy: 0.3717 - loss: 1.5990 - val_accuracy: 0.4404 - val_loss: 1.4464
# Epoch 3/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 36s 80ms/step - accuracy: 0.4350 - loss: 1.4723 - val_accuracy: 0.4868 - val_loss: 1.3328
# Epoch 4/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 34s 76ms/step - accuracy: 0.4605 - loss: 1.4077 - val_accuracy: 0.4999 - val_loss: 1.2946
# Epoch 5/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 35s 78ms/step - accuracy: 0.4860 - loss: 1.3502 - val_accuracy: 0.5117 - val_loss: 1.2747
# Epoch 6/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 38s 84ms/step - accuracy: 0.4964 - loss: 1.3200 - val_accuracy: 0.5261 - val_loss: 1.2377
# Epoch 7/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 34s 75ms/step - accuracy: 0.5084 - loss: 1.2912 - val_accuracy: 0.5244 - val_loss: 1.2476
# Epoch 8/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 36s 80ms/step - accuracy: 0.5141 - loss: 1.2714 - val_accuracy: 0.5454 - val_loss: 1.1887
# Epoch 9/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 35s 77ms/step - accuracy: 0.5269 - loss: 1.2512 - val_accuracy: 0.5582 - val_loss: 1.1714
# Epoch 10/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 35s 78ms/step - accuracy: 0.5295 - loss: 1.2348 - val_accuracy: 0.5543 - val_loss: 1.1728
# Epoch 11/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 35s 78ms/step - accuracy: 0.5392 - loss: 1.2197 - val_accuracy: 0.5621 - val_loss: 1.1557
# Epoch 12/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 35s 77ms/step - accuracy: 0.5397 - loss: 1.2058 - val_accuracy: 0.5702 - val_loss: 1.1378
# Epoch 13/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 41s 92ms/step - accuracy: 0.5487 - loss: 1.1878 - val_accuracy: 0.5726 - val_loss: 1.1255
# Epoch 14/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 37s 83ms/step - accuracy: 0.5483 - loss: 1.1833 - val_accuracy: 0.5724 - val_loss: 1.1276
# Epoch 15/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 38s 86ms/step - accuracy: 0.5533 - loss: 1.1761 - val_accuracy: 0.5783 - val_loss: 1.1247
# Epoch 16/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 44s 98ms/step - accuracy: 0.5598 - loss: 1.1640 - val_accuracy: 0.5864 - val_loss: 1.1099
# Epoch 17/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 39s 88ms/step - accuracy: 0.5648 - loss: 1.1523 - val_accuracy: 0.5829 - val_loss: 1.1144
# Epoch 18/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 39s 88ms/step - accuracy: 0.5681 - loss: 1.1435 - val_accuracy: 0.5793 - val_loss: 1.1075
# Epoch 19/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 35s 78ms/step - accuracy: 0.5696 - loss: 1.1370 - val_accuracy: 0.5791 - val_loss: 1.1131
# Epoch 20/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 34s 75ms/step - accuracy: 0.5699 - loss: 1.1354 - val_accuracy: 0.5894 - val_loss: 1.0974
# Epoch 21/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 34s 76ms/step - accuracy: 0.5758 - loss: 1.1226 - val_accuracy: 0.5851 - val_loss: 1.0881
# Epoch 22/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 35s 78ms/step - accuracy: 0.5766 - loss: 1.1178 - val_accuracy: 0.5982 - val_loss: 1.0874
# Epoch 23/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 36s 79ms/step - accuracy: 0.5787 - loss: 1.1118 - val_accuracy: 0.5893 - val_loss: 1.1078
# Epoch 24/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 36s 79ms/step - accuracy: 0.5818 - loss: 1.1049 - val_accuracy: 0.5963 - val_loss: 1.0766
# Epoch 25/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 36s 79ms/step - accuracy: 0.5850 - loss: 1.1012 - val_accuracy: 0.5908 - val_loss: 1.0826
# Epoch 26/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 35s 79ms/step - accuracy: 0.5849 - loss: 1.0978 - val_accuracy: 0.5945 - val_loss: 1.0712
# Epoch 27/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 35s 79ms/step - accuracy: 0.5896 - loss: 1.0859 - val_accuracy: 0.5885 - val_loss: 1.0972
# Epoch 28/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 36s 80ms/step - accuracy: 0.5876 - loss: 1.0875 - val_accuracy: 0.6018 - val_loss: 1.0683
# Epoch 29/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 35s 78ms/step - accuracy: 0.5913 - loss: 1.0850 - val_accuracy: 0.6016 - val_loss: 1.0669
# Epoch 30/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 35s 79ms/step - accuracy: 0.5943 - loss: 1.0740 - val_accuracy: 0.5996 - val_loss: 1.0606
# Epoch 31/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 36s 79ms/step - accuracy: 0.5920 - loss: 1.0716 - val_accuracy: 0.6070 - val_loss: 1.0572
# Epoch 32/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 47s 104ms/step - accuracy: 0.5963 - loss: 1.0656 - val_accuracy: 0.6062 - val_loss: 1.0585
# Epoch 33/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 36s 80ms/step - accuracy: 0.5996 - loss: 1.0596 - val_accuracy: 0.6050 - val_loss: 1.0576
# Epoch 34/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 35s 79ms/step - accuracy: 0.5965 - loss: 1.0613 - val_accuracy: 0.6025 - val_loss: 1.0674
# Epoch 35/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 40s 88ms/step - accuracy: 0.6025 - loss: 1.0524 - val_accuracy: 0.6103 - val_loss: 1.0565
# Epoch 36/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 38s 85ms/step - accuracy: 0.6037 - loss: 1.0536 - val_accuracy: 0.6067 - val_loss: 1.0654
# Epoch 37/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 35s 79ms/step - accuracy: 0.6054 - loss: 1.0497 - val_accuracy: 0.6067 - val_loss: 1.0737
# Epoch 38/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 35s 78ms/step - accuracy: 0.6088 - loss: 1.0429 - val_accuracy: 0.6049 - val_loss: 1.0756
# Epoch 39/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 35s 78ms/step - accuracy: 0.6094 - loss: 1.0400 - val_accuracy: 0.5975 - val_loss: 1.0749
# Epoch 40/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 36s 79ms/step - accuracy: 0.6097 - loss: 1.0375 - val_accuracy: 0.6101 - val_loss: 1.0567
# Epoch 41/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 35s 78ms/step - accuracy: 0.6065 - loss: 1.0308 - val_accuracy: 0.6038 - val_loss: 1.0830
# Epoch 42/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 35s 79ms/step - accuracy: 0.6132 - loss: 1.0302 - val_accuracy: 0.6014 - val_loss: 1.0897
# Epoch 43/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 35s 78ms/step - accuracy: 0.6109 - loss: 1.0227 - val_accuracy: 0.6082 - val_loss: 1.0539
# Epoch 44/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 35s 78ms/step - accuracy: 0.6135 - loss: 1.0243 - val_accuracy: 0.6144 - val_loss: 1.0454
# Epoch 45/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 37s 82ms/step - accuracy: 0.6127 - loss: 1.0214 - val_accuracy: 0.6078 - val_loss: 1.0887
# Epoch 46/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 36s 81ms/step - accuracy: 0.6167 - loss: 1.0150 - val_accuracy: 0.6091 - val_loss: 1.0587
# Epoch 47/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 37s 83ms/step - accuracy: 0.6183 - loss: 1.0083 - val_accuracy: 0.6163 - val_loss: 1.0522
# Epoch 48/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 36s 79ms/step - accuracy: 0.6157 - loss: 1.0206 - val_accuracy: 0.6151 - val_loss: 1.0576
# Epoch 49/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 36s 80ms/step - accuracy: 0.6194 - loss: 1.0037 - val_accuracy: 0.6195 - val_loss: 1.0383
# Epoch 50/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 36s 79ms/step - accuracy: 0.6173 - loss: 1.0100 - val_accuracy: 0.6194 - val_loss: 1.0521
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model

model = load_model("emotion_model.h5")

emotion_labels = ['Angry','Disgust','Fear','Happy','Sad','Surprise','Neutral']

face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)


cap = cv2.VideoCapture("118936-716625953_tiny.mp4")

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)

    for (x,y,w,h) in faces:
        roi = gray[y:y+h, x:x+w]

        if roi.size == 0:
          continue

        roi = cv2.resize(roi, (48,48))
        roi = roi.astype("float32") / 255.0
        roi = np.expand_dims(roi, axis=-1)
        roi = np.expand_dims(roi, axis=0)

        prediction = model.predict(roi, verbose=0)
        label = emotion_labels[np.argmax(prediction)]

        cv2.rectangle(frame, (x,y), (x+w,y+h), (255,0,0), 2)
        cv2.putText(frame, label, (x,y-10),cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,255,0), 2)


    cv2.imshow("Facial Expression Detection - Video", frame)

    if cv2.waitKey(25) & 0xFF == ord('q'):   # 25 ms for smooth video
        break

cap.release()
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import urllib.request

url = "https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml"
urllib.request.urlretrieve(url, "haarcascade_frontalface_default.xml")

print("Downloaded successfully!")
# Out:
# Downloaded successfully!
